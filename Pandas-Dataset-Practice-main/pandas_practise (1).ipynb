# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#             ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0     45654403  13328  1399        LEXUS   RX 450      2010.0       Jeep
# 1     44731507  16621  1018    CHEVROLET  Equinox      2011.0       Jeep
# 2     45774419   8467     -        HONDA      FIT      2006.0  Hatchback
# 3     45769185   3607   862         FORD   Escape      2011.0       Jeep
# 4     45809263  11726   446        HONDA      FIT      2014.0  Hatchback
# ...        ...    ...   ...          ...      ...         ...        ...
# 9155  45810592  16778   765    CHEVROLET  Orlando      2015.0       Jeep
# 9156  45068478  26657   777        MAZDA     CX-5      2014.0       Jeep
# 9157  45686742  21953  1327       NISSAN  X-Terra      2011.0       Jeep
# 9158  45810532  22357   640    CHEVROLET  Orlando      2013.0       Jeep
# 9159  45768392    156   NaN          NaN      NaN         NaN        NaN
#
#      Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9160 entries, 0 to 9159
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                9160 non-null   int64
#  1   Price             9160 non-null   int64
#  2   Levy              9159 non-null   object
#  3   Manufacturer      9159 non-null   object
#  4   Model             9159 non-null   object
#  5   Prod. year        9159 non-null   float64
#  6   Category          9159 non-null   object
#  7   Leather interior  9159 non-null   object
#  8   Fuel type         9159 non-null   object
#  9   Engine volume     9159 non-null   object
#  10  Mileage           9159 non-null   object
#  11  Cylinders         9159 non-null   float64
#  12  Gear box type     9159 non-null   object
#  13  Drive wheels      9159 non-null   object
#  14  Doors             9159 non-null   object
#  15  Wheel             9159 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                1
# Manufacturer        1
# Model               1
# Prod. year          1
# Category            1
# Leather interior    1
# Fuel type           1
# Engine volume       1
# Mileage             1
# Cylinders           1
# Gear box type       1
# Drive wheels        1
# Doors               1
# Wheel               1
# Color               1
# Airbags             1
# dtype: int64

# %%
df['Color'].unique()
# Out:
# array(['Silver', 'Black', 'White', 'Grey', 'Blue', 'Green', 'Red',
#        'Sky blue', 'Orange', 'Yellow', 'Brown', 'Golden', 'Beige',
#        'Carnelian red', 'Purple', 'Pink', nan], dtype=object)

# %%
len(df['Color'].unique())
# Out:
# 17

# %%
df[['ID', 'Manufacturer', 'Airbags', 'Price']].isnull().sum()
# Out:
# ID              0
# Manufacturer    1
# Airbags         1
# Price           0
# dtype: int64

# %%
df.iloc[:999, 0:17]
# Out:
#            ID  Price  Levy   Manufacturer       Model  Prod. year   Category  \
# 0    45654403  13328  1399          LEXUS      RX 450      2010.0       Jeep
# 1    44731507  16621  1018      CHEVROLET     Equinox      2011.0       Jeep
# 2    45774419   8467     -          HONDA         FIT      2006.0  Hatchback
# 3    45769185   3607   862           FORD      Escape      2011.0       Jeep
# 4    45809263  11726   446          HONDA         FIT      2014.0  Hatchback
# ..        ...    ...   ...            ...         ...         ...        ...
# 994  45647961     94  1058  MERCEDES-BENZ      ML 350      2012.0       Jeep
# 995  45809896  12607   503         TOYOTA        Aqua      2012.0  Hatchback
# 996  45740308   9095     -          HONDA        Cr-v      2002.0       Jeep
# 997  45813829   3058  1083          DODGE  Challenger      2013.0      Coupe
# 998  45815368   6899     -          HONDA      Stream      2004.0    Minivan
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year          float64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags             float64
# dtype: object

# %%
df['ID'] = df['ID'].astype(float)

# %%
df['ID']
# Out:
# 0       45654403.0
# 1       44731507.0
# 2       45774419.0
# 3       45769185.0
# 4       45809263.0
#            ...
# 9155    45810592.0
# 9156    45068478.0
# 9157    45686742.0
# 9158    45810532.0
# 9159    45768392.0
# Name: ID, Length: 9160, dtype: float64

# %%
df['ID'] = df['ID'].astype(int)

# %%
df['ID']
# Out:
# 0       45654403
# 1       44731507
# 2       45774419
# 3       45769185
# 4       45809263
#           ...
# 9155    45810592
# 9156    45068478
# 9157    45686742
# 9158    45810532
# 9159    45768392
# Name: ID, Length: 9160, dtype: int64

# %%
#Display stats of entire data
df.describe(include='all')
# Out:
#                   ID          Price  Levy Manufacturer   Model   Prod. year  \
# count   9.160000e+03    9160.000000  9159         9159    9159  9159.000000
# unique           NaN            NaN   441           60    1051          NaN
# top              NaN            NaN     -       TOYOTA  Sonata          NaN
# freq             NaN            NaN  2772         1813     528          NaN
# mean    4.557738e+07   17242.530568   NaN          NaN     NaN  2010.896823
# std     9.055381e+05   21382.316655   NaN          NaN     NaN     5.643379
# min     2.470192e+07       1.000000   NaN          NaN     NaN  1943.000000
# 25%     4.570927e+07    5331.000000   NaN          NaN     NaN  2009.000000
# 50%     4.577201e+07   13172.000000   NaN          NaN     NaN  2012.000000
# 75%     4.580200e+07   22074.750000   NaN          NaN     NaN  2014.000000
# max     4.581665e+07  872946.000000   NaN          NaN     NaN  2020.000000
#
# ...

# %%
#Stats of Numerical data
df.describe()
# Out:
#                  ID          Price   Prod. year    Cylinders      Airbags
# count  9.160000e+03    9160.000000  9159.000000  9159.000000  9159.000000
# mean   4.557738e+07   17242.530568  2010.896823     4.590457     6.623212
# std    9.055381e+05   21382.316655     5.643379     1.216416     4.302453
# min    2.470192e+07       1.000000  1943.000000     1.000000     0.000000
# 25%    4.570927e+07    5331.000000  2009.000000     4.000000     4.000000
# 50%    4.577201e+07   13172.000000  2012.000000     4.000000     6.000000
# 75%    4.580200e+07   22074.750000  2014.000000     4.000000    12.000000
# max    4.581665e+07  872946.000000  2020.000000    16.000000    16.000000

# %%
#length of numerical dta columns count
len(df.describe())
# Out:
# 8

# %%
#Stats of Object data
df.describe(include='object')
# Out:
#          Levy Manufacturer  Model Category Leather interior Fuel type  \
# count   19237        19237  19237    19237            19237     19237
# unique    559           65   1590       11                2         7
# top         -      HYUNDAI  Prius    Sedan              Yes    Petrol
# freq     5819         3769   1083     8736            13954     10150
#
#        Engine volume Mileage Gear box type Drive wheels   Doors       Wheel  \
# count          19237   19237         19237        19237   19237       19237
# unique           107    7687             4            3       3           2
# top                2    0 km     Automatic        Front  04-May  Left wheel
# freq            3916     721         13514        12874   18332       17753
#
#         Color
# count   19237
# unique     16
# top     Black
# freq     5033

# %%
#length of object columns
len(df.describe(include='object').columns)
# Out:
# 13

# %%
#duplicates count
print(df.duplicated().sum())
# Out:
# 313

# %%
#drop duplicates
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
#display shape (rows and columns)
df.shape
# Out:
# (18924, 18)

# %%
df.columns
# Out:
# Index(['ID', 'Price', 'Levy', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Airbags'],
#       dtype='object')

# %%
#All the unique values from all the columns
for col in df.columns:
  print(f"{col} : {df[col].nunique()} unique values.")
# Out:
# ID : 18924 unique values.
# Price : 2315 unique values.
# Levy : 559 unique values.
# Manufacturer : 65 unique values.
# Model : 1590 unique values.
# Prod. year : 54 unique values.
# Category : 11 unique values.
# Leather interior : 2 unique values.
# Fuel type : 7 unique values.
# Engine volume : 107 unique values.
# Mileage : 7687 unique values.
# Cylinders : 13 unique values.
# Gear box type : 4 unique values.
# Drive wheels : 3 unique values.
# Doors : 3 unique values.
# Wheel : 2 unique values.
# Color : 16 unique values.
# Airbags : 17 unique values.

# %%
df.sample(5)
# Out:
#              ID  Price Levy Manufacturer    Model  Prod. year Category  \
# 13903  45525725  19757    -          KIA   Optima        2014    Sedan
# 7777   45797751  19089  583      HYUNDAI  Elantra        2011    Sedan
# 7458   45768602  13350    -       TOYOTA     Aqua        2013    Sedan
# 1279   45641362   3763  779       TOYOTA    Camry        2013    Sedan
# 16962  45652867    392  831      HYUNDAI   Sonata        2011    Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 13903               No    Hybrid           2.4       0 km        4.0
# 7777               Yes    Petrol           1.6   77483 km        4.0
# 7458                No    Hybrid           1.5    1000 km        4.0
# 1279               Yes    Hybrid           2.5  124912 km        4.0
# 16962              Yes    Hybrid           2.4       0 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# ...
