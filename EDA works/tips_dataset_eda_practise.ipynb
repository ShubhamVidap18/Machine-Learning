# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = pd.read_csv('/content/tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
tips.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
tips.dtypes
# Out:
# total_bill          float64
# tip                 float64
# sex                  object
# smoker               object
# day                  object
# time                 object
# size                  int64
# price_per_person    float64
# Payer Name           object
# CC Number             int64
# Payment ID           object
# dtype: object

# %%
tips.shape
# Out:
# (244, 11)

# %%
tips.sample(20)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2              5.32
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3             10.02
# 43         9.68  1.32    Male     No   Sun  Dinner     2              4.84
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 137       14.15  2.00  Female     No  Thur   Lunch     2              7.08
# 116       29.93  5.07    Male     No   Sun  Dinner     4              7.48
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# 113       23.95  2.55    Male     No   Sun  Dinner     2             11.98
# ...

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# # Scatterplot (Numerical - Numerical)

# %%
sns.scatterplot(x = tips['CC Number'], y = tips['size'])
# Out:
# <Axes: xlabel='CC Number', ylabel='size'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['price_per_person'])
# Out:
# <Axes: xlabel='total_bill', ylabel='price_per_person'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['sex'], style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['tip'], y = tips['price_per_person'], hue = tips['sex'], style = tips['smoker'])
# Out:
# <Axes: xlabel='tip', ylabel='price_per_person'>

# %%
sns.scatterplot(x = tips['tip'], y = tips['price_per_person'], hue = tips['day'], style = tips['smoker'])
# Out:
# <Axes: xlabel='tip', ylabel='price_per_person'>

# %%
sns.scatterplot(x = tips['total_bill'], y = tips['tip'], hue = tips['day'], style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = tips['tip'], y = tips['price_per_person'], hue = tips['sex'], style = tips['size'])
# Out:
# <Axes: xlabel='tip', ylabel='price_per_person'>

# %% [markdown]
# # Linepot (Numerical - Numerical)

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day   time  size  price_per_person  \
# 198       13.00  2.00  Female    Yes  Thur  Lunch     2              6.50
# 145        8.35  1.50  Female     No  Thur  Lunch     2              4.18
# 140       17.47  3.50  Female     No  Thur  Lunch     2              8.74
# 133       12.26  2.00  Female     No  Thur  Lunch     2              6.13
# 201       12.74  2.01  Female    Yes  Thur  Lunch     2              6.37
#
#          Payer Name         CC Number Payment ID
# 198  Katherine Bond     4926725945192    Thur437
# 145       Amy Young     4285454264477   Thur9331
# 140      Kayla Rios  5233918213804470   Thur3906
# 133    Kaitlin Wolf      676348318145   Thur1561
# 201   Abigail Parks  3586645396220590   Thur2544

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'], hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['price_per_person'], hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='price_per_person'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'], hue = tips['sex'], style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'], hue = tips['day'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x = tips['total_bill'], y = tips['tip'], hue = tips['day'], style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Pairplot (Numerical - Numerical)

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.pairplot(tips, hue = 'day')

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
sns.pairplot(tips, hue = 'size')

# %% [markdown]
# # Barplot (Categorical - Numerical)

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 173       31.85  3.18    Male    Yes   Sun  Dinner     2             15.92
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2              5.68
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2             13.64
#
#       Payer Name         CC Number Payment ID
# 231  Jason Parks     4812333796161    Sat6334
# 173  Scott Perez  3577115550328507    Sun9335
# 100   Lori Lynch    38558279384492    Fri4106
# 197  Brooke Soto  5544902205760175   Thur9313
# 96   Eric Carter  4563054452787961    Fri3159

# %%
sns.barplot(x = tips['sex'], y = tips['total_bill'], hue = tips['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x = tips['day'], y = tips['total_bill'], hue = tips['smoker'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = tips['day'], y = tips['smoker'], hue = tips['sex'])
# Out:
# <Axes: xlabel='day', ylabel='smoker'>

# %%
sns.barplot(x = tips['smoker'], y = tips['total_bill'], hue = tips['time'])
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(x = tips['day'], y = tips['tip'], hue = tips['sex'])
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.barplot(x = tips['time'], y = tips['day'], hue = tips['smoker'])
# Out:
# <Axes: xlabel='time', ylabel='day'>

# %%
tips.total_bill.plot.hist(bins = 50)
plt.xlabel('total_bill')
# Out:
# Text(0.5, 0, 'total_bill')

# %%
tips.tip.plot.hist(bins=50)
plt.xlabel('tip')
# Out:
# Text(0.5, 0, 'tip')

# %%
tips.tip.plot.hist()
plt.xlabel('tip')
# Out:
# Text(0.5, 0, 'tip')
